# %% [markdown]
# # Crime Incidents In Honolulu, Hi
# Public data retrieved from data.honolulu.gov (https://data.honolulu.gov/Public-Safety/Crime-Incidents/a96q-gyhq)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#creating file path, data, and looking at the description of values of columns
crime_file_path = 'https://raw.githubusercontent.com/garywhi/CrimeIncidents/master/Crime_Incidents.csv'
crime_data = pd.read_csv(crime_file_path, index_col=0)
crime_data.describe(include='all')
# Out:
#                 KiloNBR          BlockAddress  \
# count             28162                 28162
# unique            28054                  7114
# top     LHP160321000985  1400 BLOCK ALA MOANA
# freq                  2                   598
# mean                NaN                   NaN
# std                 NaN                   NaN
# min                 NaN                   NaN
# 25%                 NaN                   NaN
# 50%                 NaN                   NaN
# 75%                 NaN                   NaN
# max                 NaN                   NaN
#
#                                       CMID         CMAgency  \
# count                                28162            28162
# unique                               28058                1
# top     Honolulu_PD_HI_LHP160321000270_064  Honolulu PD, HI
# freq                                     2            28162
# mean                                   NaN              NaN
# std                                    NaN              NaN
# min                                    NaN              NaN
# 25%                                    NaN              NaN
# 50%                                    NaN              NaN
# 75%                                    NaN              NaN
# max                                    NaN              NaN
#
#                                 Date           Type Status         Score  \
# count                          28162          28162  28162  28162.000000
# unique                         27153              5      3           NaN
# top     12/08/2015 03:21:00 AM +0000  THEFT/LARCENY      M           NaN
# freq                               3          14262  27254           NaN
# mean                             NaN            NaN    NaN     97.360237
# std                              NaN            NaN    NaN     15.999889
# min                              NaN            NaN    NaN      0.000000
# 25%                              NaN            NaN    NaN    100.000000
# 50%                              NaN            NaN    NaN    100.000000
# 75%                              NaN            NaN    NaN    100.000000
# max                              NaN            NaN    NaN    100.000000
#
#          Side
# count   27422
# unique      3
# top         L
# freq    12984
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN

# %%
# Dataframe with only the top 5 BlockAddress
df = crime_data[crime_data.BlockAddress.isin(crime_data.BlockAddress.value_counts().head(5).index)]

# Rows with empty values are dropped because finding an average to impute does not make sense here
df.dropna()
df.head()
# Out:
#                   KiloNBR             BlockAddress  \
# ObjectID
# 555835    LHP150924000023     1400 BLOCK ALA MOANA
# 555839    LHP150924000131   700 BLOCK KEEAUMOKU ST
# 555855    LHP150924000548     1400 BLOCK ALA MOANA
# 555861    LHP150924001920  2400 BLOCK KALAKAUA AVE
# 555909    LHP150924001471   700 BLOCK KEEAUMOKU ST
#
#                                         CMID         CMAgency  \
# ObjectID
# 555835    Honolulu_PD_HI_LHP150924000023_064  Honolulu PD, HI
# 555839    Honolulu_PD_HI_LHP150924000131_064  Honolulu PD, HI
# 555855    Honolulu_PD_HI_LHP150924000548_060  Honolulu PD, HI
# 555861    Honolulu_PD_HI_LHP150924001920_060  Honolulu PD, HI
# 555909    Honolulu_PD_HI_LHP150924001471_060  Honolulu PD, HI
#
#                                   Date                    Type Status  Score  \
# ObjectID
# 555835    09/24/2015 10:22:00 AM +0000  VEHICLE BREAK-IN/THEFT      M    100
# 555839    09/24/2015 12:55:00 PM +0000  VEHICLE BREAK-IN/THEFT      M    100
# 555855    09/24/2015 07:00:00 PM +0000           THEFT/LARCENY      M    100
# 555861    09/25/2015 08:23:00 AM +0000           THEFT/LARCENY      M    100
# 555909    09/25/2015 03:34:00 AM +0000           THEFT/LARCENY      M    100
#
#          Side
# ObjectID
# 555835      L
# 555839      L
# 555855      L
# 555861      L
# 555909      L

# %%
df['BlockAddress'].value_counts().plot.bar(
    figsize=(12, 6),
    fontsize=14,
    title='Number of Crime Incidents'
)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                   KiloNBR             BlockAddress  \
# ObjectID
# 555835    LHP150924000023     1400 BLOCK ALA MOANA
# 555839    LHP150924000131   700 BLOCK KEEAUMOKU ST
# 555855    LHP150924000548     1400 BLOCK ALA MOANA
# 555861    LHP150924001920  2400 BLOCK KALAKAUA AVE
# 555909    LHP150924001471   700 BLOCK KEEAUMOKU ST
#
#                                         CMID         CMAgency  \
# ObjectID
# 555835    Honolulu_PD_HI_LHP150924000023_064  Honolulu PD, HI
# 555839    Honolulu_PD_HI_LHP150924000131_064  Honolulu PD, HI
# 555855    Honolulu_PD_HI_LHP150924000548_060  Honolulu PD, HI
# 555861    Honolulu_PD_HI_LHP150924001920_060  Honolulu PD, HI
# 555909    Honolulu_PD_HI_LHP150924001471_060  Honolulu PD, HI
#
#                               Date                    Type Status  Score Side
# ObjectID
# 555835   2015-09-24 10:22:00+00:00  VEHICLE BREAK-IN/THEFT      M    100    L
# 555839   2015-09-24 12:55:00+00:00  VEHICLE BREAK-IN/THEFT      M    100    L
# 555855   2015-09-24 19:00:00+00:00           THEFT/LARCENY      M    100    L
# 555861   2015-09-25 08:23:00+00:00           THEFT/LARCENY      M    100    L
# 555909   2015-09-25 03:34:00+00:00           THEFT/LARCENY      M    100    L

# %%
#Create new columns from Date for Month, Day, Year, and Day of the Week
df_split = df.copy()
df_split['Month'] = df_split['Date'].dt.month
df_split['Day'] = df_split['Date'].dt.day
df_split['Year'] =  df_split['Date'].dt.year
df_split['DayofWeek'] = df_split['Date'].dt.dayofweek
df_split.head()
# Out:
#                   KiloNBR             BlockAddress  \
# ObjectID
# 555835    LHP150924000023     1400 BLOCK ALA MOANA
# 555839    LHP150924000131   700 BLOCK KEEAUMOKU ST
# 555855    LHP150924000548     1400 BLOCK ALA MOANA
# 555861    LHP150924001920  2400 BLOCK KALAKAUA AVE
# 555909    LHP150924001471   700 BLOCK KEEAUMOKU ST
#
#                                         CMID         CMAgency  \
# ObjectID
# 555835    Honolulu_PD_HI_LHP150924000023_064  Honolulu PD, HI
# 555839    Honolulu_PD_HI_LHP150924000131_064  Honolulu PD, HI
# 555855    Honolulu_PD_HI_LHP150924000548_060  Honolulu PD, HI
# 555861    Honolulu_PD_HI_LHP150924001920_060  Honolulu PD, HI
# 555909    Honolulu_PD_HI_LHP150924001471_060  Honolulu PD, HI
#
#                               Date                    Type Status  Score Side  \
# ObjectID
# 555835   2015-09-24 10:22:00+00:00  VEHICLE BREAK-IN/THEFT      M    100    L
# 555839   2015-09-24 12:55:00+00:00  VEHICLE BREAK-IN/THEFT      M    100    L
# 555855   2015-09-24 19:00:00+00:00           THEFT/LARCENY      M    100    L
# 555861   2015-09-25 08:23:00+00:00           THEFT/LARCENY      M    100    L
# 555909   2015-09-25 03:34:00+00:00           THEFT/LARCENY      M    100    L
#
#           Month  Day  Year  DayofWeek
# ObjectID
# 555835        9   24  2015          3
# 555839        9   24  2015          3
# 555855        9   24  2015          3
# 555861        9   25  2015          4
# 555909        9   25  2015          4

# %%
fig, axarr = plt.subplots(2, 2, figsize=(16, 12))

df_split['Month'].value_counts().sort_index().plot.line(ax=axarr[0][0])
df_split['Year'].value_counts().sort_index().plot.bar(ax=axarr[0][1])
df_split['Day'].value_counts().sort_index().plot.line(ax=axarr[1][0])
df_split['DayofWeek'].value_counts().sort_index().plot.bar(ax=axarr[1][1])

axarr[0][0].set_title("Number of Incidents per Month", fontsize=16)
axarr[0][1].set_title("Number of Incidents per Year", fontsize=16)
axarr[1][0].set_title("Number of Incidents per Day on Month", fontsize=16)
axarr[1][1].set_title("Number of Incidents per Day of Week", fontsize=16)
# Out:
# Text(0.5,1,'Number of Incidents per Day of Week')

# %%
crime_data_features = ['BlockAddress', 'Date']
X = crime_data[crime_data_features]
y = crime_data.Type
X.head()
# Out:
#                         BlockAddress                          Date
# ObjectID
# 583660            H3W HALAWA VLY  UP  11/17/2015 06:34:00 PM +0000
# 583719    HOLOMOANA ST&KAHANAMOKU ST  11/18/2015 03:40:00 AM +0000
# 584226          2600 BLOCK GORDON ST  11/18/2015 11:21:00 AM +0000
# 584261               0 BLOCK H2N FWY  11/18/2015 07:43:00 PM +0000
# 584273       4400 BLOCK KAPOLEI PKWY  11/18/2015 08:57:00 PM +0000

# %%
#df = crime_data[crime_data.BlockAddress.isin(crime_data.BlockAddress.value_counts().head(5).index)]
figure_size = (15, 5)
fig, ax = plt.subplots(figsize=figure_size)
sns.countplot(ax=ax, x='BlockAddress', data=df)
plt.show()

# %%
top5_blocks = ['1400 BLOCK ALA MOANA', '700 BLOCK KEEAUMOKU ST', '2400 BLOCK KALAKAUA AVE', '2200 BLOCK KALAKAUA AVE', '981000 BLOCK MOANALUA RD']
df_top5 = crime_data[crime_data.BlockAddress.isin(top5_blocks)]
df_top5.head()
# Out:
#                   KiloNBR             BlockAddress  \
# ObjectID
# 555835    LHP150924000023     1400 BLOCK ALA MOANA
# 555839    LHP150924000131   700 BLOCK KEEAUMOKU ST
# 555855    LHP150924000548     1400 BLOCK ALA MOANA
# 555861    LHP150924001920  2400 BLOCK KALAKAUA AVE
# 555909    LHP150924001471   700 BLOCK KEEAUMOKU ST
#
#                                         CMID         CMAgency  \
# ObjectID
# 555835    Honolulu_PD_HI_LHP150924000023_064  Honolulu PD, HI
# 555839    Honolulu_PD_HI_LHP150924000131_064  Honolulu PD, HI
# 555855    Honolulu_PD_HI_LHP150924000548_060  Honolulu PD, HI
# 555861    Honolulu_PD_HI_LHP150924001920_060  Honolulu PD, HI
# 555909    Honolulu_PD_HI_LHP150924001471_060  Honolulu PD, HI
#
#                                   Date                    Type Status  Score  \
# ObjectID
# 555835    09/24/2015 10:22:00 AM +0000  VEHICLE BREAK-IN/THEFT      M    100
# 555839    09/24/2015 12:55:00 PM +0000  VEHICLE BREAK-IN/THEFT      M    100
# 555855    09/24/2015 07:00:00 PM +0000           THEFT/LARCENY      M    100
# 555861    09/25/2015 08:23:00 AM +0000           THEFT/LARCENY      M    100
# 555909    09/25/2015 03:34:00 AM +0000           THEFT/LARCENY      M    100
#
#          Side
# ObjectID
# 555835      L
# 555839      L
# 555855      L
# 555861      L
# 555909      L

# %%
df.head()
# Out:
#                   KiloNBR             BlockAddress  \
# ObjectID
# 555835    LHP150924000023     1400 BLOCK ALA MOANA
# 555839    LHP150924000131   700 BLOCK KEEAUMOKU ST
# 555855    LHP150924000548     1400 BLOCK ALA MOANA
# 555861    LHP150924001920  2400 BLOCK KALAKAUA AVE
# 555909    LHP150924001471   700 BLOCK KEEAUMOKU ST
#
#                                         CMID         CMAgency  \
# ObjectID
# 555835    Honolulu_PD_HI_LHP150924000023_064  Honolulu PD, HI
# 555839    Honolulu_PD_HI_LHP150924000131_064  Honolulu PD, HI
# 555855    Honolulu_PD_HI_LHP150924000548_060  Honolulu PD, HI
# 555861    Honolulu_PD_HI_LHP150924001920_060  Honolulu PD, HI
# 555909    Honolulu_PD_HI_LHP150924001471_060  Honolulu PD, HI
#
#                               Date                    Type Status  Score Side
# ObjectID
# 555835   2015-09-24 10:22:00+00:00  VEHICLE BREAK-IN/THEFT      M    100    L
# 555839   2015-09-24 12:55:00+00:00  VEHICLE BREAK-IN/THEFT      M    100    L
# 555855   2015-09-24 19:00:00+00:00           THEFT/LARCENY      M    100    L
# 555861   2015-09-25 08:23:00+00:00           THEFT/LARCENY      M    100    L
# 555909   2015-09-25 03:34:00+00:00           THEFT/LARCENY      M    100    L

# %%
#sns.jointplot(x='Day', y='DayofWeek', kind='hex', data=df_split)
#days = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
df_split.plot.hexbin(x='Day', y='DayofWeek', gridsize=6, title='Incident Density of Month')

# %%
fig, axarr = plt.subplots(3,2,figsize=(16,18))
df_split[df_split['Type'] == 'VEHICLE BREAK-IN/THEFT'].plot.hexbin(x='Day',
                                                                   y='DayofWeek',
                                                                   gridsize=6,
                                                                   title='Vehicle Break-in/Theft Density',
                                                                   ax=axarr[0][0]
                                                                  )
df_split[df_split['Type'] == 'THEFT/LARCENY'].plot.hexbin(x='Day',
                                                          y='DayofWeek',
                                                          gridsize=6,
                                                          title='Theft/Larceny Density',
                                                         ax=axarr[0][1])
df_split[df_split['Type'] == 'BURGLARY'].plot.hexbin(x='Day',
                                                          y='DayofWeek',
                                                          gridsize=6,
                                                          title='Burglary Density',
                                                         ax=axarr[1][0])
df_split[df_split['Type'] == 'MOTOR VEHICLE THEFT'].plot.hexbin(x='Day',
                                                          y='DayofWeek',
                                                          gridsize=6,
                                                          title='Motor Vehicle Theft Density',
                                                         ax=axarr[1][1])
df_split[df_split['Type'] == 'VANDALISM'].plot.hexbin(x='Day',
                                                          y='DayofWeek',
                                                          gridsize=6,
                                                          title='Vandalism Density',
                                                         ax=axarr[2][0])
df_split.plot.hexbin(x='Day',
                     y='DayofWeek',
                     gridsize=6,
                     title='All Crime Incident Densities of Month',
                    ax=axarr[2][1])
